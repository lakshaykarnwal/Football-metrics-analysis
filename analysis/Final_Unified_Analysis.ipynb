# %% [markdown]
# # Final Analysis

# %% [markdown]
# ### Research Questions:
# 1) Chinmay Jain: What type of playstyle (offensive/defensive) leads to most success in each league (Top 5 European Leagues)?
# 2) Lakshay Karnwal: Why do teams with the highest xG(expected goals) still end up not winning the league and which factors cause the upset?

# %% [markdown]
# ### Description of Variables:

# %% [markdown]
# - **xG** - expected goals metric, it is a statistical measure of the quality of chances created and conceded.
# - **xGA** - expected goals against.
# - **ppda_coef** - passes allowed per defensive action in the opposition half (power of pressure)
# - **oppda_coef** - opponent passes allowed per defensive action in the opposition half (power of opponent's pressure)
# - **deep** - passes completed within an estimated 20 yards of goal (crosses excluded)
# - **deep_allowed** - opponent passes completed within an estimated 20 yards of goal (crosses excluded)
# - **xpts** - expected points
# - **pts_per_game** - average points per game

# %% [markdown]
# # Research Question #1

# %%
from ChinmayJain.Scripts import project_functions as pf
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %load_ext autoreload
# %autoreload 2
from importlib import reload

# %% [markdown]
# ### Simplified Data Set

# %%
df = pf.load_and_process("../data/raw/understat.com.csv")
df.to_csv (r'../data/processed/processed_df_cj.csv', index = False, header=True)
df = df.drop(columns=['League', 'Year', 'team', 'matches', 'pts'])
df
# Out:
#      position          xG        xGA  ppda_coef  oppda_coef  deep  \
# 0           1  102.980152  28.444293   5.683535   16.367593   489
# 1           2   95.766243  42.607198  10.209085   12.929510   351
# 2           3   57.047670  29.069107   8.982028    9.237091   197
# 3           4   55.062500  39.392572   8.709827    7.870225   203
# 4           5   69.526624  47.862742   8.276148    9.477805   305
# ..        ...         ...        ...        ...         ...   ...
# 583        16   27.378050  39.300382  14.308293    9.703021   111
# 584        17   29.651493  37.725643  10.718417   10.496213    93
# 585        18   30.193755  40.473400  12.457197    9.054791   109
# 586        19   25.619869  38.426209  12.449507    9.917285   101
# 587        20   31.294048  48.275034  14.032994   10.193535   115
#
#      deep_allowed
# 0             114
# 1             153
# 2             123
# 3             172
# 4             168
# ..            ...
# 583           176
# 584           133
# 585           159
# 586           148
# 587           178
#
# [588 rows x 7 columns]

# %% [markdown]
# ### Correlation Matrix:

# %%
corr = df.corr()
corr1=corr.drop(columns={'xG','xGA','ppda_coef','oppda_coef','deep','deep_allowed'})
display(corr1)
#corr1.to_csv (r'../data/processed/corr1_CJ.csv', index = False, header=True)
corr.style.background_gradient(cmap='coolwarm')
# Out:
#               position
# position      1.000000
# xG           -0.729828
# xGA           0.707865
# ppda_coef     0.465039
# oppda_coef   -0.576000
# deep         -0.630025
# deep_allowed  0.593508
# <style  type="text/css" >
# #T_157ac_row0_col0,#T_157ac_row1_col1,#T_157ac_row2_col2,#T_157ac_row3_col3,#T_157ac_row4_col4,#T_157ac_row5_col5,#T_157ac_row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_157ac_row0_col1,#T_157ac_row0_col4,#T_157ac_row0_col5,#T_157ac_row1_col0,#T_157ac_row1_col3,#T_157ac_row4_col2,#T_157ac_row4_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_157ac_row0_col2{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_157ac_row0_col3{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_157ac_row0_col6{
#             background-color:  #f6a385;
#             color:  #000000;
#         }#T_157ac_row1_col2{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_157ac_row1_col4{
#             background-color:  #ee8468;
#             color:  #000000;
#         }#T_157ac_row1_col5{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_157ac_row1_col6{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_157ac_row2_col0{
#             background-color:  #e8765c;
#             color:  #000000;
#         }#T_157ac_row2_col1{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_157ac_row2_col3{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_157ac_row2_col4{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_157ac_row2_col5{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_157ac_row2_col6{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_157ac_row3_col0{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_157ac_row3_col1,#T_157ac_row4_col3{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_157ac_row3_col2{
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }#T_157ac_row3_col4{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_157ac_row3_col5{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_157ac_row3_col6,#T_157ac_row6_col3{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_157ac_row4_col0{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_157ac_row4_col1,#T_157ac_row4_col5{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_157ac_row5_col0{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_157ac_row5_col1{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_157ac_row5_col2{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_157ac_row5_col3{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_157ac_row5_col4{
#             background-color:  #eb7d62;
#             color:  #000000;
#         }#T_157ac_row5_col6{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_157ac_row6_col0{
#             background-color:  #f39475;
#             color:  #000000;
#         }#T_157ac_row6_col1,#T_157ac_row6_col5{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_157ac_row6_col2{
#             background-color:  #de614d;
#             color:  #000000;
#         }#T_157ac_row6_col4{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }</style><table id="T_157ac_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >position</th>        <th class="col_heading level0 col1" >xG</th>        <th class="col_heading level0 col2" >xGA</th>        <th class="col_heading level0 col3" >ppda_coef</th>        <th class="col_heading level0 col4" >oppda_coef</th>        <th class="col_heading level0 col5" >deep</th>        <th class="col_heading level0 col6" >deep_allowed</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_157ac_level0_row0" class="row_heading level0 row0" >position</th>
#                         <td id="T_157ac_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_157ac_row0_col1" class="data row0 col1" >-0.729828</td>
#                         <td id="T_157ac_row0_col2" class="data row0 col2" >0.707865</td>
#                         <td id="T_157ac_row0_col3" class="data row0 col3" >0.465039</td>
#                         <td id="T_157ac_row0_col4" class="data row0 col4" >-0.576000</td>
#                         <td id="T_157ac_row0_col5" class="data row0 col5" >-0.630025</td>
#                         <td id="T_157ac_row0_col6" class="data row0 col6" >0.593508</td>
#             </tr>
#             <tr>
#                         <th id="T_157ac_level0_row1" class="row_heading level0 row1" >xG</th>
#                         <td id="T_157ac_row1_col0" class="data row1 col0" >-0.729828</td>
#                         <td id="T_157ac_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_157ac_row1_col2" class="data row1 col2" >-0.487197</td>
#                         <td id="T_157ac_row1_col3" class="data row1 col3" >-0.466051</td>
#                         <td id="T_157ac_row1_col4" class="data row1 col4" >0.683941</td>
#                         <td id="T_157ac_row1_col5" class="data row1 col5" >0.863404</td>
#                         <td id="T_157ac_row1_col6" class="data row1 col6" >-0.447663</td>
#             </tr>
#             <tr>
#                         <th id="T_157ac_level0_row2" class="row_heading level0 row2" >xGA</th>
#                         <td id="T_157ac_row2_col0" class="data row2 col0" >0.707865</td>
#                         <td id="T_157ac_row2_col1" class="data row2 col1" >-0.487197</td>
#                         <td id="T_157ac_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_157ac_row2_col3" class="data row2 col3" >0.443145</td>
#                         <td id="T_157ac_row2_col4" class="data row2 col4" >-0.507379</td>
#                         <td id="T_157ac_row2_col5" class="data row2 col5" >-0.447804</td>
#                         <td id="T_157ac_row2_col6" class="data row2 col6" >0.806889</td>
#             </tr>
#             <tr>
#                         <th id="T_157ac_level0_row3" class="row_heading level0 row3" >ppda_coef</th>
#                         <td id="T_157ac_row3_col0" class="data row3 col0" >0.465039</td>
#                         <td id="T_157ac_row3_col1" class="data row3 col1" >-0.466051</td>
#                         <td id="T_157ac_row3_col2" class="data row3 col2" >0.443145</td>
#                         <td id="T_157ac_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_157ac_row3_col4" class="data row3 col4" >-0.237597</td>
#                         <td id="T_157ac_row3_col5" class="data row3 col5" >-0.411445</td>
#                         <td id="T_157ac_row3_col6" class="data row3 col6" >0.537217</td>
#             </tr>
#             <tr>
#                         <th id="T_157ac_level0_row4" class="row_heading level0 row4" >oppda_coef</th>
#                         <td id="T_157ac_row4_col0" class="data row4 col0" >-0.576000</td>
#                         <td id="T_157ac_row4_col1" class="data row4 col1" >0.683941</td>
#                         <td id="T_157ac_row4_col2" class="data row4 col2" >-0.507379</td>
#                         <td id="T_157ac_row4_col3" class="data row4 col3" >-0.237597</td>
#                         <td id="T_157ac_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_157ac_row4_col5" class="data row4 col5" >0.705427</td>
#                         <td id="T_157ac_row4_col6" class="data row4 col6" >-0.476374</td>
#             </tr>
#             <tr>
#                         <th id="T_157ac_level0_row5" class="row_heading level0 row5" >deep</th>

# %% [markdown]
# Our offensive variables are xG, ppda_coef, deep and our defensive variables xGA, oppda_coef, deep_allowed. So using of correlation of each varible to position we can determine the weight of each variable for the offensive and defensive average.
# - Offensive: 45% xG, 25% ppda_coef, 30% deep
# - Defensive: 40% xGA, 30% oppda_coef, 30% deep_allowed

# %% [markdown]
# ### Filtering and Processing the raw dataset:

# %%
reload(pf)
#Exporting processed data for Tableau
df_av_league = pf.weighted_av_league("../data/raw/understat.com.csv")
display(df_av_league)
df_av_league.to_csv (r'../data/processed/processed_df_av_league_cj.csv', index = False, header=True)

#Exporting processed data for Tableau
df_av_top = pf.weighted_av_top("../data/raw/understat.com.csv")
display(df_av_top)
df_av_top.to_csv (r'../data/processed/processed_df_av__top_cj.csv', index = False, header=True)

#Exporting processed data for Tableau
df_av1 = pf.weighted_av("../data/raw/understat.com.csv")
country = ['Germany','Germany','United Kingdom','United Kingdom', 'Spain', 'Spain', 'France', 'France', 'Italy', 'Italy']
df_av1['Country']=country
df_av1.to_csv (r'../data/processed/processed_df_av_cj.csv', index = False, header=True)

df_av = pf.weighted_av("../data/raw/understat.com.csv")
display(df_av)
# Out:
#        League        pts         xG        xGA  ppda_coef  oppda_coef  \
# 0     La_liga  52.225000  50.590325  50.590325   9.654516    9.654516
# 1         EPL  52.450000  50.762647  50.762647  11.847171   11.847171
# 2  Bundesliga  46.824074  48.699397  48.699397  11.170879   11.170879
# 3     Serie_A  52.125000  51.026213  51.026213  11.054684   11.050871
# 4     Ligue_1  49.758333  45.141445  45.141445  11.028938   11.032684
#
#          deep  deep_allowed  Offensive W_Average  Defensive W_Average
# 0  214.000000    214.000000            89.379275            87.332485
# 1  249.566667    249.566667           100.674984            98.729210
# 2  202.935185    202.935185            85.588004            83.711578
# 3  227.450000    227.450000            93.960467            91.960746
# 4  171.991667    171.991667            74.668385            72.963883
#                League        pts         xG        xGA  ppda_coef  oppda_coef  \
# 0     La_liga_topTeam  90.833333  92.228056  36.505663   8.137579   14.943445
# 1         EPL_topTeam  93.000000  76.534052  32.496773   9.441893   19.666714
# 2  Bundesliga_topTeam  82.166667  79.799526  27.382881   7.330245   23.839114
# 3     Serie_A_topTeam  89.500000  64.722223  30.055285   9.644669   13.686024
# 4     Ligue_1_topTeam  87.666667  83.724212  29.802266   7.814924   17.835084
#
#          deep  deep_allowed  Offensive W_Average  Defensive W_Average
# 0  445.166667    156.000000           177.087020            65.885299
# 1  435.166667    162.000000           167.350797            67.498723
# 2  398.500000    107.333333           157.292348            50.304886
# 3  287.666667    139.666667           117.836168            58.027921
# 4  358.166667    121.000000           147.079626            53.571432
#                League  Offensive W_Average  Defensive W_Average
# 0          Bundesliga            85.588004            83.711578
# 1  Bundesliga_topTeam           157.292348            50.304886
# 2                 EPL           100.674984            98.729210
# 3         EPL_topTeam           167.350797            67.498723
# 4             La_liga            89.379275            87.332485
# 5     La_liga_topTeam           177.087020            65.885299
# 6             Ligue_1            74.668385            72.963883
# 7     Ligue_1_topTeam           147.079626            53.571432
# 8             Serie_A            93.960467            91.960746
# 9     Serie_A_topTeam           117.836168            58.027921

# %% [markdown]
# ### Graphing the Offensive and Defensive Weighted Average:

# %%
fig, axes = plt.subplots(5, 2, figsize=(10,30),sharey=True)
plt.rcParams['font.family'] = "serif"
sns.set_context(font_scale=1.5)
#fig.suptitle('Comparing the Top Teams and their League in Regards to their Offensive and Defensive Weighted Average ')
ax = sns.barplot(ax = axes[0,0], data = df_av.iloc[0:1], palette='flare')
ax2 = sns.barplot(ax = axes[0,1], data = df_av.iloc[1:2], palette='flare')
ax3 = sns.barplot(ax = axes[1,0], data = df_av.iloc[2:3], palette='flare')
ax4 = sns.barplot(ax = axes[1,1], data = df_av.iloc[3:4], palette='flare')
ax5 = sns.barplot(ax = axes[2,0], data = df_av.iloc[4:5], palette='flare')
ax6 = sns.barplot(ax = axes[2,1], data = df_av.iloc[5:6], palette='flare')
ax7 = sns.barplot(ax = axes[3,0], data = df_av.iloc[6:7], palette='flare')
ax8 = sns.barplot(ax = axes[3,1], data = df_av.iloc[7:8], palette='flare')
ax9 = sns.barplot(ax = axes[4,0], data = df_av.iloc[8:9], palette='flare')
ax10 = sns.barplot(ax = axes[4,1], data = df_av.iloc[9:10], palette='flare')

axes[0,0].set_title('Bundesliga')
axes[0,1].set_title('Bungesliga Winners')
axes[1,0].set_title('EPL')
axes[1,1].set_title('EPL Winners')
axes[2,0].set_title('La Liga')
axes[2,1].set_title('La Liga Winners')
axes[3,0].set_title('Ligue 1')
axes[3,1].set_title('Ligue 1 Winners')
axes[4,0].set_title('Serie A')
axes[4,1].set_title('Serie A Winners')
# Out:
# Text(0.5, 1.0, 'Serie A Winners')

# %%
plt.figure(figsize=(11,6))
fig = sns.scatterplot(data = df_av, y='League', x='Offensive W_Average')
fig = sns.scatterplot(data = df_av, y='League', x='Defensive W_Average')
fig.set_title("Comparing the League and their Top Team's Weighted Averages")
fig.set_xlabel("Weighted Defensive and Offensive Average")
plt.legend(["W_Offensive Average", "W_Defensive Average"])
plt.show()

# %% [markdown]
# #### Observations/Analysis

# %% [markdown]
# - **Bundesliga**
#     - The league as whole plays slightly more offensively but it is still quite balanced.
#     - The league winners play very offensively so in the Bundesliga offensive teams have more success.
# - **EPL**
#     - The EPL has the highest offensive and defensive averages compared to the other leagues and it also plays slightly more offensively.
#     - The league winners play very offensively but EPL winners have the highest defensive average compared to other league winners. So in the EPL offensive teams have more success but they still need to have a reliable defensive backline.
# - **La Liga**
#     - The La Liga is a slightly more offense based league.
#     - The La Liga winners have the highest offensive average compared to the other winners so in the La Liga the teams need to have a strong group of forwards in order to be successful
# - **Ligue 1**
#     - The Ligue 1 has the lowest offensive and defensive averages which indicates that they have the weakest teams.
#     - The Ligue 1 winners are more offensive so in the Ligue 1 teams have to be very offensive in order to be successful.
# - **Serie A**
#     - The Serie A is 2nd in both offensive and defensive averages and the averages are close so teams have to be offensive and defensively strong.
#     - The Serie A winners have the lowest offensive score compared to the other winners but they are still very offensive heavy
#
# **Conclusion:** Our results are interesting as it shows that in every league the winners are quite offensive heavy, but each league is slightly different in how offensively and defensively they play.

# %% [markdown]
# # Research Question #2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
from importlib import reload
from LakshayKarnwal.Scripts import project_functions as pf
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Simplified Data Set

# %%
#stored the location of data
path= "../data/raw/understat.com.csv"

#load, clean and process data
df = pf.load_and_process(path)
display(df)
#exporting processed data into a csv file for our dashboard
df.to_csv (r'../data/processed/processed_df.csv', index = False, header=True)
# Out:
#       league  year  position             team  matches  scored  conceded  pts  \
# 0    La_liga  2014         1        Barcelona       38     110        21   94
# 1    La_liga  2014         2      Real Madrid       38     118        38   92
# 2    La_liga  2014         3  Atletico Madrid       38      67        29   78
# 3    La_liga  2014         4         Valencia       38      70        32   77
# 4    La_liga  2014         5          Sevilla       38      71        45   76
# ..       ...   ...       ...              ...      ...     ...       ...  ...
# 583  Ligue_1  2019        16            Dijon       28      27        37   30
# 584  Ligue_1  2019        17    Saint-Etienne       28      29        45   30
# 585  Ligue_1  2019        18            Nimes       28      29        44   27
# 586  Ligue_1  2019        19           Amiens       28      31        50   23
# 587  Ligue_1  2019        20         Toulouse       28      22        58   13
#
#              xG        xGA   pressure  oppo_pressure     xpts  pts_per_game
# 0    102.980152  28.444293   5.683535      16.367593  94.0813      2.473684
# 1     95.766243  42.607198  10.209085      12.929510  81.7489      2.421053
# 2     57.047670  29.069107   8.982028       9.237091  73.1353      2.052632
# 3     55.062500  39.392572   8.709827       7.870225  63.7068      2.026316
# 4     69.526624  47.862742   8.276148       9.477805  67.3867      2.000000
# ..          ...        ...        ...            ...      ...           ...
# 583   27.378050  39.300382  14.308293       9.703021  31.1870      1.071429
# 584   29.651493  37.725643  10.718417      10.496213  32.6755      1.071429
# 585   30.193755  40.473400  12.457197       9.054791  32.6876      0.964286
# 586   25.619869  38.426209  12.449507       9.917285  32.8361      0.821429
# 587   31.294048  48.275034  14.032994      10.193535  28.0073      0.464286
#
# [588 rows x 14 columns]

# %% [markdown]
# ### Graphing Team's effect on opponent:

# %%
#set up color theme for the plots
colors = ['#ff9999','#99ff99', '#B7C3F3', '#DD7596']

#extracts data of teams that have higher xG than the winning team in EPL 2014 
df1= pf.filter_data_set('EPL',2014,path)
display(df1)
#plots the graph for team's effect on opponent
fig, ax = plt.subplots()
pf.bar_plot(ax, df1, total_width=0.3, single_width=0.7, chart_value=1,colors=colors)
plt.show()

#extracts data of teams that have higher xG than the winning team in Serie A 2014
df2= pf.filter_data_set('Serie_A',2014, path)
display(df2)
#plots the graph for team's effect on opponent
fig, ax = plt.subplots()
pf.bar_plot(ax, df2, total_width=0.3, single_width=0.7, chart_value=1,colors=colors)
plt.show()

#extracts data of teams that have higher xG than the winning team in Ligue 1 2016
df3= pf.filter_data_set('Ligue_1',2016, path)
display(df3)
#plots the graph for team's effect on opponent
fig, ax = plt.subplots()
pf.bar_plot(ax, df3, total_width=0.3, single_width=0.7, chart_value=1,colors=colors)
plt.show()

#extracts data of teams that have higher xG than the winning team in La liga 2017
df4= pf.filter_data_set('La_liga',2017, path)
display(df4)
#plots the graph for team's effect on opponent
fig, ax = plt.subplots()
pf.bar_plot(ax, df4, total_width=0.3, single_width=0.7, chart_value=1,colors=colors)
plt.show()
# Out:
#     league  year  position             team  matches  scored  conceded  pts  \
# 120    EPL  2014         1          Chelsea       38      73        32   87
# 121    EPL  2014         2  Manchester City       38      83        38   79
# 122    EPL  2014         3          Arsenal       38      71        36   75
#
#             xG        xGA   pressure  oppo_pressure     xpts  pts_per_game
# 120  68.643320  31.524344  10.942027      13.419520  75.3172      2.289474
# 121  75.815441  40.499403   7.982490      15.076979  73.0982      2.078947
# 122  69.802591  35.718825   8.660596      13.254169  75.1740      1.973684
#       league  year  position        team  matches  scored  conceded  pts  \
# 348  Serie_A  2014         1    Juventus       38      72        24   87
# 350  Serie_A  2014         3       Lazio       38      71        38   69
# 351  Serie_A  2014         4  Fiorentina       38      61        46   64
# 352  Serie_A  2014         5      Napoli       38      70        54   63
#
#             xG        xGA  pressure  oppo_pressure     xpts  pts_per_game
# 348  59.077044  29.129634  8.715008      13.017563  74.7890      2.289474
# 350  61.996225  35.871453  7.282635      11.223855  67.7905      1.815789
# 351  60.670595  48.502489  7.757888      12.457943  61.1128      1.684211
# 352  64.495380  34.373501  8.836460      13.312875  70.7221      1.657895
#       league  year  position                 team  matches  scored  conceded  \
# 508  Ligue_1  2016         1               Monaco       38     107        31
# 509  Ligue_1  2016         2  Paris Saint Germain       38      83        27
#
#      pts         xG        xGA  pressure  oppo_pressure     xpts  pts_per_game
# 508   95  76.036980  34.893628  9.587803      12.331291  78.0559      2.500000
# 509   87  82.162399  24.247968  8.026454      20.293991  87.2195      2.289474
#      league  year  position         team  matches  scored  conceded  pts  \
# 60  La_liga  2017         1    Barcelona       38      99        29   93
# 62  La_liga  2017         3  Real Madrid       38      94        44   76
#
#            xG        xGA  pressure  oppo_pressure     xpts  pts_per_game
# 60  90.486752  41.620820  9.109883      13.939373  79.4375      2.447368
# 62  91.287370  45.097868  9.303382      13.999744  79.9894      2.000000

# %%
all_cases=pf.all_cases(path)
#display(all_cases)

# %% [markdown]
# ### Graphing Opponent's effect on team:

# %%
colors = ['#ff9999','#99ff99', '#B7C3F3', '#DD7596']

#extracts data of teams that have higher xG than the winning team in EPL 2014 
df1= pf.filter_data_set('EPL',2014, path)
display(df1)
#plots the graph for opponent's effect on team
fig, ax = plt.subplots()
pf.bar_plot(ax, df1, total_width=0.3, single_width=0.7, chart_value=2,colors=colors)
plt.show()

#extracts data of teams that have higher xG than the winning team in Serie A 2014 
df1= pf.filter_data_set('Serie_A',2014, path)
display(df1)
#plots the graph for opponent's effect on team
fig, ax = plt.subplots()
pf.bar_plot(ax, df1, total_width=0.3, single_width=0.7, chart_value=2,colors=colors)
plt.show()

#extracts data of teams that have higher xG than the winning team in Ligue 1 2016 
df1= pf.filter_data_set('Ligue_1',2016, path)
display(df1)
#plots the graph for opponent's effect on team
fig, ax = plt.subplots()
pf.bar_plot(ax, df1, total_width=0.3, single_width=0.7, chart_value=2,colors=colors)
plt.show()

#extracts data of teams that have higher xG than the winning team inLa liga 2017
df1= pf.filter_data_set('La_liga',2017, path)
display(df1)
#plots the graph for opponent's effect on team
fig, ax = plt.subplots()
pf.bar_plot(ax, df1, total_width=0.3, single_width=0.7, chart_value=2,colors=colors)
plt.show()
# Out:
#     league  year  position             team  matches  scored  conceded  pts  \
# 120    EPL  2014         1          Chelsea       38      73        32   87
# 121    EPL  2014         2  Manchester City       38      83        38   79
# 122    EPL  2014         3          Arsenal       38      71        36   75
#
#             xG        xGA   pressure  oppo_pressure     xpts  pts_per_game
# 120  68.643320  31.524344  10.942027      13.419520  75.3172      2.289474
# 121  75.815441  40.499403   7.982490      15.076979  73.0982      2.078947
# 122  69.802591  35.718825   8.660596      13.254169  75.1740      1.973684
#       league  year  position        team  matches  scored  conceded  pts  \
# 348  Serie_A  2014         1    Juventus       38      72        24   87
# 350  Serie_A  2014         3       Lazio       38      71        38   69
# 351  Serie_A  2014         4  Fiorentina       38      61        46   64
# 352  Serie_A  2014         5      Napoli       38      70        54   63
#
#             xG        xGA  pressure  oppo_pressure     xpts  pts_per_game
# 348  59.077044  29.129634  8.715008      13.017563  74.7890      2.289474
# 350  61.996225  35.871453  7.282635      11.223855  67.7905      1.815789
# 351  60.670595  48.502489  7.757888      12.457943  61.1128      1.684211
# 352  64.495380  34.373501  8.836460      13.312875  70.7221      1.657895
#       league  year  position                 team  matches  scored  conceded  \
# 508  Ligue_1  2016         1               Monaco       38     107        31
# 509  Ligue_1  2016         2  Paris Saint Germain       38      83        27
#
#      pts         xG        xGA  pressure  oppo_pressure     xpts  pts_per_game
# 508   95  76.036980  34.893628  9.587803      12.331291  78.0559      2.500000
# 509   87  82.162399  24.247968  8.026454      20.293991  87.2195      2.289474
#      league  year  position         team  matches  scored  conceded  pts  \
# 60  La_liga  2017         1    Barcelona       38      99        29   93
# 62  La_liga  2017         3  Real Madrid       38      94        44   76
#
#            xG        xGA  pressure  oppo_pressure     xpts  pts_per_game
# 60  90.486752  41.620820  9.109883      13.939373  79.4375      2.447368
# 62  91.287370  45.097868  9.303382      13.999744  79.9894      2.000000

# %% [markdown]
# ### Graphing net effect of each team:

# %% [markdown]
# #### Correlation Matrix:

# %%
#printing out the correlation matrix to find the correlation between all variables and position of the team in the league
corr = df.corr()
#corr1.to_csv (r'../data/processed/corr1_lk.csv', index = False, header=True)
corr.style.background_gradient(cmap="Greens")
# Out:
# <style  type="text/css" >
# #T_81d77_row0_col0,#T_81d77_row1_col1,#T_81d77_row2_col2,#T_81d77_row3_col3,#T_81d77_row4_col4,#T_81d77_row5_col5,#T_81d77_row6_col6,#T_81d77_row7_col7,#T_81d77_row8_col8,#T_81d77_row9_col9,#T_81d77_row10_col10,#T_81d77_row11_col11{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_81d77_row0_col1,#T_81d77_row0_col11,#T_81d77_row2_col11{
#             background-color:  #79c67a;
#             color:  #000000;
#         }#T_81d77_row0_col2,#T_81d77_row1_col3,#T_81d77_row1_col5,#T_81d77_row1_col6,#T_81d77_row1_col9,#T_81d77_row1_col10,#T_81d77_row1_col11,#T_81d77_row2_col0,#T_81d77_row10_col7,#T_81d77_row10_col8,#T_81d77_row11_col1,#T_81d77_row11_col4,#T_81d77_row11_col7{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_81d77_row0_col3{
#             background-color:  #8ace88;
#             color:  #000000;
#         }#T_81d77_row0_col4{
#             background-color:  #87cd86;
#             color:  #000000;
#         }#T_81d77_row0_col5{
#             background-color:  #83cb82;
#             color:  #000000;
#         }#T_81d77_row0_col6{
#             background-color:  #81ca81;
#             color:  #000000;
#         }#T_81d77_row0_col7{
#             background-color:  #7cc87c;
#             color:  #000000;
#         }#T_81d77_row0_col8{
#             background-color:  #5db96b;
#             color:  #000000;
#         }#T_81d77_row0_col9,#T_81d77_row2_col6{
#             background-color:  #6dc072;
#             color:  #000000;
#         }#T_81d77_row0_col10{
#             background-color:  #90d18d;
#             color:  #000000;
#         }#T_81d77_row1_col0,#T_81d77_row9_col1,#T_81d77_row9_col8,#T_81d77_row11_col0,#T_81d77_row11_col2{
#             background-color:  #d6efd0;
#             color:  #000000;
#         }#T_81d77_row1_col2{
#             background-color:  #cfecc9;
#             color:  #000000;
#         }#T_81d77_row1_col4{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_81d77_row1_col7{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }#T_81d77_row1_col8{
#             background-color:  #3ba458;
#             color:  #000000;
#         }#T_81d77_row2_col1{
#             background-color:  #72c375;
#             color:  #000000;
#         }#T_81d77_row2_col3{
#             background-color:  #6ec173;
#             color:  #000000;
#         }#T_81d77_row2_col4{
#             background-color:  #62bb6d;
#             color:  #000000;
#         }#T_81d77_row2_col5,#T_81d77_row2_col10{
#             background-color:  #55b567;
#             color:  #000000;
#         }#T_81d77_row2_col7{
#             background-color:  #60ba6c;
#             color:  #000000;
#         }#T_81d77_row2_col8{
#             background-color:  #bde5b6;
#             color:  #000000;
#         }#T_81d77_row2_col9,#T_81d77_row6_col2{
#             background-color:  #b1e0ab;
#             color:  #000000;
#         }#T_81d77_row3_col0,#T_81d77_row4_col0{
#             background-color:  #d5efcf;
#             color:  #000000;
#         }#T_81d77_row3_col1,#T_81d77_row4_col5{
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }#T_81d77_row3_col2{
#             background-color:  #b8e3b2;
#             color:  #000000;
#         }#T_81d77_row3_col4{
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }#T_81d77_row3_col5,#T_81d77_row10_col11{
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }#T_81d77_row3_col6,#T_81d77_row6_col3,#T_81d77_row10_col5{
#             background-color:  #005221;
#             color:  #f1f1f1;
#         }#T_81d77_row3_col7,#T_81d77_row9_col2{
#             background-color:  #e4f5df;
#             color:  #000000;
#         }#T_81d77_row3_col8{
#             background-color:  #f0f9ed;
#             color:  #000000;
#         }#T_81d77_row3_col9,#T_81d77_row11_col9{
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }#T_81d77_row3_col10,#T_81d77_row10_col3{
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }#T_81d77_row3_col11,#T_81d77_row5_col3{
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }#T_81d77_row4_col1{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_81d77_row4_col2{
#             background-color:  #afdfa8;
#             color:  #000000;
#         }#T_81d77_row4_col3,#T_81d77_row5_col0,#T_81d77_row8_col6,#T_81d77_row8_col10{
#             background-color:  #def2d9;
#             color:  #000000;
#         }#T_81d77_row4_col6{
#             background-color:  #e1f3dc;
#             color:  #000000;
#         }#T_81d77_row4_col7,#T_81d77_row7_col4{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_81d77_row4_col8{
#             background-color:  #4eb264;
#             color:  #000000;
#         }#T_81d77_row4_col9{
#             background-color:  #eff9eb;
#             color:  #000000;
#         }#T_81d77_row4_col10,#T_81d77_row4_col11{
#             background-color:  #edf8e9;
#             color:  #000000;
#         }#T_81d77_row5_col1{
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }#T_81d77_row5_col2{
#             background-color:  #acdea6;
#             color:  #000000;
#         }#T_81d77_row5_col4{
#             background-color:  #f4fbf1;
#             color:  #000000;
#         }#T_81d77_row5_col6{
#             background-color:  #006428;
#             color:  #f1f1f1;
#         }#T_81d77_row5_col7{
#             background-color:  #f3faf0;
#             color:  #000000;
#         }#T_81d77_row5_col8{
#             background-color:  #f2faf0;
#             color:  #000000;
#         }#T_81d77_row5_col9{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_81d77_row5_col10,#T_81d77_row6_col10{
#             background-color:  #005321;
#             color:  #f1f1f1;
#         }#T_81d77_row5_col11,#T_81d77_row11_col5{
#             background-color:  #00471c;
#             color:  #f1f1f1;
#         }#T_81d77_row6_col0{
#             background-color:  #c9eac2;
#             color:  #000000;
#         }#T_81d77_row6_col1{
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }#T_81d77_row6_col4,#T_81d77_row9_col4{
#             background-color:  #d9f0d3;
#             color:  #000000;
#         }#T_81d77_row6_col5{
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }#T_81d77_row6_col7{
#             background-color:  #e0f3db;
#             color:  #000000;
#         }#T_81d77_row6_col8,#T_81d77_row7_col9,#T_81d77_row7_col10{
#             background-color:  #f1faee;
#             color:  #000000;
#         }#T_81d77_row6_col9{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_81d77_row6_col11{
#             background-color:  #006328;
#             color:  #f1f1f1;
#         }#T_81d77_row7_col0{
#             background-color:  #c3e7bc;
#             color:  #000000;
#         }#T_81d77_row7_col1{
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }#T_81d77_row7_col2{
#             background-color:  #a5db9f;
#             color:  #000000;
#         }#T_81d77_row7_col3,#T_81d77_row10_col0{
#             background-color:  #dff3da;
#             color:  #000000;
#         }#T_81d77_row7_col5{
#             background-color:  #e7f6e2;
#             color:  #000000;
#         }#T_81d77_row7_col6{
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }#T_81d77_row7_col8{
#             background-color:  #3fa85b;
#             color:  #000000;
#         }#T_81d77_row7_col11{
#             background-color:  #e8f6e4;
#             color:  #000000;
#         }#T_81d77_row8_col0{
#             background-color:  #86cc85;
#             color:  #000000;
#         }#T_81d77_row8_col1{
#             background-color:  #29914a;
#             color:  #000000;
#         }#T_81d77_row8_col2{
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }#T_81d77_row8_col3{
#             background-color:  #d8f0d2;
#             color:  #000000;

# %% [markdown]
# The analysis is divided into two parts:
# 1) Team's effect on opponent (includes variables: expected goals (xG), goals scored (scored), and pressure)
# 2) Opponent's effect on team (includes variables: expected goals against (xGA), goals conceded (conceded), and opposition pressure (oppo_pressure))
#
# To find out the weighted average, I used the correlation between the position variable and the rest of the variables using the correlation matrix.
#
# The results were:
# 1) Team's effect on opponent: 24% pressure, 37% xG, 39% scored
# 2) Opponent's effect on team: 28% oppo_pressure, 34% xGA, 38% conceded

# %% [markdown]
# #### Graphing weighted average of Team's effect on opponent, Oppenent's effect on team, and net team effect:

# %% [markdown]
# The following graphs includes presentation of weighted averages of team's effect and opponent's effect and finally the net weighted average calculated using the correlation matrix.
#
# NOTE:
# For the weighted average of Team's effect on opponent, higher the value better is the team's attacking performance
#
# For the weighted average of Opponent's effect on teams, lower the value better is the team's defensive performace
#
# For the net value, higher the value, better is the overall chances of the team ranking higher in the table

# %%
#color variables for different graphs
colors1 = ['#ff9999','#99ff99', '#B7C3F3']
colors2 = ['#99ff99']
colors3 = ['#B7C3F3']

#method call to graph team's effect on opponent
df1=pf.weighted_avg_attack('EPL',2014, path)
df2=df1.style.set_table_attributes("style='display:inline'").set_caption('Weighted avg. of team'+'s effect on opponent')
#displays the table
display(df2)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df2, total_width=0.3, single_width=0.7, chart_value=3,colors=colors1)
plt.show()

#method call to graph opponent's effect on team
df3=pf.weighted_avg_def('EPL',2014, path)
df4=df3.style.set_caption('Weighted avg. of opponent'+'s effect on team')
#displays the table
display(df4)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df4, total_width=0.3, single_width=0.7, chart_value=3,colors=colors2)
plt.show()

#method call to team's net effect
df4=pf.weighted_avg_net('EPL',2014, path)
df5=df4.style.set_table_attributes("style='display:inline'").set_caption('Net effect of each team')
#displays the table
display(df5)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df5, total_width=0.3, single_width=0.7, chart_value=3,colors=colors3)
plt.show()
# Out:
# <style  type="text/css" >
# </style><table id="T_4ac7d_" style='display:inline'><caption>Weighted avg. of teams effect on opponent</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >avg</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ac7d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4ac7d_row0_col0" class="data row0 col0" >Chelsea</td>
#                         <td id="T_4ac7d_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_4ac7d_row0_col2" class="data row0 col2" >56.494115</td>
#                         <td id="T_4ac7d_row0_col3" class="data row0 col3" >EPL</td>
#                         <td id="T_4ac7d_row0_col4" class="data row0 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_4ac7d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4ac7d_row1_col0" class="data row1 col0" >Manchester City</td>
#                         <td id="T_4ac7d_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_4ac7d_row1_col2" class="data row1 col2" >62.337511</td>
#                         <td id="T_4ac7d_row1_col3" class="data row1 col3" >EPL</td>
#                         <td id="T_4ac7d_row1_col4" class="data row1 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_4ac7d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4ac7d_row2_col0" class="data row2 col0" >Arsenal</td>
#                         <td id="T_4ac7d_row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_4ac7d_row2_col2" class="data row2 col2" >55.595502</td>
#                         <td id="T_4ac7d_row2_col3" class="data row2 col3" >EPL</td>
#                         <td id="T_4ac7d_row2_col4" class="data row2 col4" >2014</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_9c687_" ><caption>Weighted avg. of opponents effect on team</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >avg</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9c687_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9c687_row0_col0" class="data row0 col0" >Chelsea</td>
#                         <td id="T_9c687_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_9c687_row0_col2" class="data row0 col2" >26.635743</td>
#                         <td id="T_9c687_row0_col3" class="data row0 col3" >EPL</td>
#                         <td id="T_9c687_row0_col4" class="data row0 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_9c687_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9c687_row1_col0" class="data row1 col0" >Manchester City</td>
#                         <td id="T_9c687_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_9c687_row1_col2" class="data row1 col2" >32.431351</td>
#                         <td id="T_9c687_row1_col3" class="data row1 col3" >EPL</td>
#                         <td id="T_9c687_row1_col4" class="data row1 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_9c687_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9c687_row2_col0" class="data row2 col0" >Arsenal</td>
#                         <td id="T_9c687_row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_9c687_row2_col2" class="data row2 col2" >29.535568</td>
#                         <td id="T_9c687_row2_col3" class="data row2 col3" >EPL</td>
#                         <td id="T_9c687_row2_col4" class="data row2 col4" >2014</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_88513_" style='display:inline'><caption>Net effect of each team</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >net</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88513_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_88513_row0_col0" class="data row0 col0" >Chelsea</td>
#                         <td id="T_88513_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_88513_row0_col2" class="data row0 col2" >29.858372</td>
#                         <td id="T_88513_row0_col3" class="data row0 col3" >EPL</td>
#                         <td id="T_88513_row0_col4" class="data row0 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_88513_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_88513_row1_col0" class="data row1 col0" >Manchester City</td>
#                         <td id="T_88513_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_88513_row1_col2" class="data row1 col2" >29.906160</td>
#                         <td id="T_88513_row1_col3" class="data row1 col3" >EPL</td>
#                         <td id="T_88513_row1_col4" class="data row1 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_88513_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_88513_row2_col0" class="data row2 col0" >Arsenal</td>
#                         <td id="T_88513_row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_88513_row2_col2" class="data row2 col2" >26.059934</td>
#                         <td id="T_88513_row2_col3" class="data row2 col3" >EPL</td>
#                         <td id="T_88513_row2_col4" class="data row2 col4" >2014</td>
#             </tr>
#     </tbody></table>

# %%
#color variables for different graphs
colors1 = ['#ff9999','#99ff99', '#B7C3F3']
colors2 = ['#99ff99']
colors3 = ['#B7C3F3']

#method call to graph team's effect on opponent
df1=pf.weighted_avg_attack('Serie_A',2014, path)
df2=df1.style.set_table_attributes("style='display:inline'").set_caption('Weighted avg. of team'+'s effect on opponent')
#displays the table
display(df2)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df2, total_width=0.3, single_width=0.7, chart_value=3,colors=colors1)
plt.show()

#method call to graph opponent's effect on team
df3=pf.weighted_avg_def('Serie_A',2014, path)
df4=df3.style.set_caption('Weighted avg. of opponent'+'s effect on team')
#displays the table
display(df4)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df4, total_width=0.3, single_width=0.7, chart_value=3,colors=colors2)
plt.show()

#method call to team's net effect
df4=pf.weighted_avg_net('Serie_A',2014, path)
df5=df4.style.set_table_attributes("style='display:inline'").set_caption('Net effect of each team')
#displays the table
display(df5)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df5, total_width=0.3, single_width=0.7, chart_value=3,colors=colors3)
plt.show()
# Out:
# <style  type="text/css" >
# </style><table id="T_be014_" style='display:inline'><caption>Weighted avg. of teams effect on opponent</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >avg</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_be014_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_be014_row0_col0" class="data row0 col0" >Juventus</td>
#                         <td id="T_be014_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_be014_row0_col2" class="data row0 col2" >52.030108</td>
#                         <td id="T_be014_row0_col3" class="data row0 col3" >Serie_A</td>
#                         <td id="T_be014_row0_col4" class="data row0 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_be014_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_be014_row1_col0" class="data row1 col0" >Lazio</td>
#                         <td id="T_be014_row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_be014_row1_col2" class="data row1 col2" >52.376436</td>
#                         <td id="T_be014_row1_col3" class="data row1 col3" >Serie_A</td>
#                         <td id="T_be014_row1_col4" class="data row1 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_be014_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_be014_row2_col0" class="data row2 col0" >Fiorentina</td>
#                         <td id="T_be014_row2_col1" class="data row2 col1" >4</td>
#                         <td id="T_be014_row2_col2" class="data row2 col2" >48.100013</td>
#                         <td id="T_be014_row2_col3" class="data row2 col3" >Serie_A</td>
#                         <td id="T_be014_row2_col4" class="data row2 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_be014_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_be014_row3_col0" class="data row3 col0" >Napoli</td>
#                         <td id="T_be014_row3_col1" class="data row3 col1" >5</td>
#                         <td id="T_be014_row3_col2" class="data row3 col2" >53.284041</td>
#                         <td id="T_be014_row3_col3" class="data row3 col3" >Serie_A</td>
#                         <td id="T_be014_row3_col4" class="data row3 col4" >2014</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_6a628_" ><caption>Weighted avg. of opponents effect on team</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >avg</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6a628_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6a628_row0_col0" class="data row0 col0" >Juventus</td>
#                         <td id="T_6a628_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_6a628_row0_col2" class="data row0 col2" >22.668993</td>
#                         <td id="T_6a628_row0_col3" class="data row0 col3" >Serie_A</td>
#                         <td id="T_6a628_row0_col4" class="data row0 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_6a628_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6a628_row1_col0" class="data row1 col0" >Lazio</td>
#                         <td id="T_6a628_row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_6a628_row1_col2" class="data row1 col2" >29.778973</td>
#                         <td id="T_6a628_row1_col3" class="data row1 col3" >Serie_A</td>
#                         <td id="T_6a628_row1_col4" class="data row1 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_6a628_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6a628_row2_col0" class="data row2 col0" >Fiorentina</td>
#                         <td id="T_6a628_row2_col1" class="data row2 col1" >4</td>
#                         <td id="T_6a628_row2_col2" class="data row2 col2" >37.459070</td>
#                         <td id="T_6a628_row2_col3" class="data row2 col3" >Serie_A</td>
#                         <td id="T_6a628_row2_col4" class="data row2 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_6a628_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6a628_row3_col0" class="data row3 col0" >Napoli</td>
#                         <td id="T_6a628_row3_col1" class="data row3 col1" >5</td>
#                         <td id="T_6a628_row3_col2" class="data row3 col2" >35.934595</td>
#                         <td id="T_6a628_row3_col3" class="data row3 col3" >Serie_A</td>
#                         <td id="T_6a628_row3_col4" class="data row3 col4" >2014</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_19603_" style='display:inline'><caption>Net effect of each team</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >net</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19603_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_19603_row0_col0" class="data row0 col0" >Juventus</td>
#                         <td id="T_19603_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_19603_row0_col2" class="data row0 col2" >29.361115</td>
#                         <td id="T_19603_row0_col3" class="data row0 col3" >Serie_A</td>
#                         <td id="T_19603_row0_col4" class="data row0 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_19603_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_19603_row1_col0" class="data row1 col0" >Lazio</td>
#                         <td id="T_19603_row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_19603_row1_col2" class="data row1 col2" >22.597462</td>
#                         <td id="T_19603_row1_col3" class="data row1 col3" >Serie_A</td>
#                         <td id="T_19603_row1_col4" class="data row1 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_19603_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_19603_row2_col0" class="data row2 col0" >Fiorentina</td>
#                         <td id="T_19603_row2_col1" class="data row2 col1" >4</td>
#                         <td id="T_19603_row2_col2" class="data row2 col2" >10.640943</td>
#                         <td id="T_19603_row2_col3" class="data row2 col3" >Serie_A</td>
#                         <td id="T_19603_row2_col4" class="data row2 col4" >2014</td>
#             </tr>
#             <tr>
#                         <th id="T_19603_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_19603_row3_col0" class="data row3 col0" >Napoli</td>
#                         <td id="T_19603_row3_col1" class="data row3 col1" >5</td>
#                         <td id="T_19603_row3_col2" class="data row3 col2" >17.349445</td>
#                         <td id="T_19603_row3_col3" class="data row3 col3" >Serie_A</td>
#                         <td id="T_19603_row3_col4" class="data row3 col4" >2014</td>
#             </tr>
#     </tbody></table>

# %%
#method call to graph team's effect on opponent, opponent's effect on team and net effect of team
#pf.weighted_avg('Ligue_1',2016, path)
colors1 = ['#ff9999','#99ff99', '#B7C3F3']
colors2 = ['#99ff99']
colors3 = ['#B7C3F3']

#method call to graph team's effect on opponent, opponent's effect on team and net effect of team
df1=pf.weighted_avg_attack('Ligue_1',2016, path)
df2=df1.style.set_table_attributes("style='display:inline'").set_caption('Weighted avg. of team'+'s effect on opponent')
#displays the table
display(df2)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df2, total_width=0.3, single_width=0.7, chart_value=3,colors=colors1)
plt.show()

#method call to graph opponent's effect on team
df3=pf.weighted_avg_def('Ligue_1',2016, path)
df4=df3.style.set_caption('Weighted avg. of opponent'+'s effect on team')
#displays the table
display(df4)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df4, total_width=0.3, single_width=0.7, chart_value=3,colors=colors2)
plt.show()

#method call to team's net effect
df4=pf.weighted_avg_net('Ligue_1',2016, path)
df5=df4.style.set_table_attributes("style='display:inline'").set_caption('Net effect of each team')
#displays the table
display(df5)
#plots the graph
fig, ax = plt.subplots()
pf.bar_plot(ax, df5, total_width=0.3, single_width=0.7, chart_value=3,colors=colors3)
plt.show()
# Out:
# <style  type="text/css" >
# </style><table id="T_f425c_" style='display:inline'><caption>Weighted avg. of teams effect on opponent</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >avg</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f425c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f425c_row0_col0" class="data row0 col0" >Monaco</td>
#                         <td id="T_f425c_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_f425c_row0_col2" class="data row0 col2" >72.164755</td>
#                         <td id="T_f425c_row0_col3" class="data row0 col3" >Ligue_1</td>
#                         <td id="T_f425c_row0_col4" class="data row0 col4" >2016</td>
#             </tr>
#             <tr>
#                         <th id="T_f425c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f425c_row1_col0" class="data row1 col0" >Paris Saint Germain</td>
#                         <td id="T_f425c_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_f425c_row1_col2" class="data row1 col2" >64.696437</td>
#                         <td id="T_f425c_row1_col3" class="data row1 col3" >Ligue_1</td>
#                         <td id="T_f425c_row1_col4" class="data row1 col4" >2016</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_68af9_" ><caption>Weighted avg. of opponents effect on team</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >avg</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68af9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_68af9_row0_col0" class="data row0 col0" >Monaco</td>
#                         <td id="T_68af9_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_68af9_row0_col2" class="data row0 col2" >27.096595</td>
#                         <td id="T_68af9_row0_col3" class="data row0 col3" >Ligue_1</td>
#                         <td id="T_68af9_row0_col4" class="data row0 col4" >2016</td>
#             </tr>
#             <tr>
#                         <th id="T_68af9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_68af9_row1_col0" class="data row1 col0" >Paris Saint Germain</td>
#                         <td id="T_68af9_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_68af9_row1_col2" class="data row1 col2" >24.186627</td>
#                         <td id="T_68af9_row1_col3" class="data row1 col3" >Ligue_1</td>
#                         <td id="T_68af9_row1_col4" class="data row1 col4" >2016</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_e9ad8_" style='display:inline'><caption>Net effect of each team</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >net</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e9ad8_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e9ad8_row0_col0" class="data row0 col0" >Monaco</td>
#                         <td id="T_e9ad8_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_e9ad8_row0_col2" class="data row0 col2" >45.068160</td>
#                         <td id="T_e9ad8_row0_col3" class="data row0 col3" >Ligue_1</td>
#                         <td id="T_e9ad8_row0_col4" class="data row0 col4" >2016</td>
#             </tr>
#             <tr>
#                         <th id="T_e9ad8_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e9ad8_row1_col0" class="data row1 col0" >Paris Saint Germain</td>
#                         <td id="T_e9ad8_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_e9ad8_row1_col2" class="data row1 col2" >40.509810</td>
#                         <td id="T_e9ad8_row1_col3" class="data row1 col3" >Ligue_1</td>
#                         <td id="T_e9ad8_row1_col4" class="data row1 col4" >2016</td>
#             </tr>
#     </tbody></table>

# %%
#method call to graph team's effect on opponent, opponent's effect on team and net effect of team
#pf.weighted_avg('La_liga',2017, path)
colors1 = ['#ff9999','#99ff99', '#B7C3F3']
colors2 = ['#99ff99']
colors3 = ['#B7C3F3']

#method call to graph team's effect on opponent
df1=pf.weighted_avg_attack('La_liga',2017, path)
df2=df1.style.set_table_attributes("style='display:inline'").set_caption('Weighted avg. of team'+'s effect on opponent')
display(df2)
fig, ax = plt.subplots()
pf.bar_plot(ax, df2, total_width=0.3, single_width=0.7, chart_value=3,colors=colors1)
plt.show()

#method call to graph opponent's effect on team
df3=pf.weighted_avg_def('La_liga',2017, path)
df4=df3.style.set_caption('Weighted avg. of opponent'+'s effect on team')
display(df4)
fig, ax = plt.subplots()
pf.bar_plot(ax, df4, total_width=0.3, single_width=0.7, chart_value=3,colors=colors2)
plt.show()

#method call to team's net effect
df4=pf.weighted_avg_net('La_liga',2017, path)
df5=df4.style.set_table_attributes("style='display:inline'").set_caption('Net effect of each team')
display(df5)
fig, ax = plt.subplots()
pf.bar_plot(ax, df5, total_width=0.3, single_width=0.7, chart_value=3,colors=colors3)
plt.show()
# Out:
# <style  type="text/css" >
# </style><table id="T_68fbf_" style='display:inline'><caption>Weighted avg. of teams effect on opponent</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >avg</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68fbf_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_68fbf_row0_col0" class="data row0 col0" >Barcelona</td>
#                         <td id="T_68fbf_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_68fbf_row0_col2" class="data row0 col2" >74.276470</td>
#                         <td id="T_68fbf_row0_col3" class="data row0 col3" >La_liga</td>
#                         <td id="T_68fbf_row0_col4" class="data row0 col4" >2017</td>
#             </tr>
#             <tr>
#                         <th id="T_68fbf_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_68fbf_row1_col0" class="data row1 col0" >Real Madrid</td>
#                         <td id="T_68fbf_row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_68fbf_row1_col2" class="data row1 col2" >72.669139</td>
#                         <td id="T_68fbf_row1_col3" class="data row1 col3" >La_liga</td>
#                         <td id="T_68fbf_row1_col4" class="data row1 col4" >2017</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_e1750_" ><caption>Weighted avg. of opponents effect on team</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >avg</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1750_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e1750_row0_col0" class="data row0 col0" >Barcelona</td>
#                         <td id="T_e1750_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_e1750_row0_col2" class="data row0 col2" >29.074103</td>
#                         <td id="T_e1750_row0_col3" class="data row0 col3" >La_liga</td>
#                         <td id="T_e1750_row0_col4" class="data row0 col4" >2017</td>
#             </tr>
#             <tr>
#                         <th id="T_e1750_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e1750_row1_col0" class="data row1 col0" >Real Madrid</td>
#                         <td id="T_e1750_row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_e1750_row1_col2" class="data row1 col2" >35.973204</td>
#                         <td id="T_e1750_row1_col3" class="data row1 col3" >La_liga</td>
#                         <td id="T_e1750_row1_col4" class="data row1 col4" >2017</td>
#             </tr>
#     </tbody></table>
# <style  type="text/css" >
# </style><table id="T_700f2_" style='display:inline'><caption>Net effect of each team</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >team</th>        <th class="col_heading level0 col1" >position</th>        <th class="col_heading level0 col2" >net</th>        <th class="col_heading level0 col3" >league</th>        <th class="col_heading level0 col4" >year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_700f2_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_700f2_row0_col0" class="data row0 col0" >Barcelona</td>
#                         <td id="T_700f2_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_700f2_row0_col2" class="data row0 col2" >45.202367</td>
#                         <td id="T_700f2_row0_col3" class="data row0 col3" >La_liga</td>
#                         <td id="T_700f2_row0_col4" class="data row0 col4" >2017</td>
#             </tr>
#             <tr>
#                         <th id="T_700f2_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_700f2_row1_col0" class="data row1 col0" >Real Madrid</td>
#                         <td id="T_700f2_row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_700f2_row1_col2" class="data row1 col2" >36.695935</td>
#                         <td id="T_700f2_row1_col3" class="data row1 col3" >La_liga</td>
#                         <td id="T_700f2_row1_col4" class="data row1 col4" >2017</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Observations/Analysis

# %% [markdown]
# According to the performed EDA, it is very clear that there are many factors apart from xG that influence the position of a team in their particular league.
#
# In the graphs shown above, the team that ended up winning the league usually had a higher net value than the teams that only had higher xG. The net values were calculated by finding the difference between team's effect and opponents effect
#
# **Net value = Team's effect on opponent - Opponent's effect on team**
#
# Each of the values that effect the net value were calculated using metrics such as: xG, pressure, scored, xGA, oppo_pressure, conceded.The weight of these values were found out using the correlation matrix:
#
# xG: 37%
# pressure: 24%
# scored: 39%
# xGA: 34%
# oppo_pressure: 28%
# conceded: 38%

# %%
#setting up the values and labels of the pie chart
team_effect_weights= [37,24,39]
parameters= ['xG','pressure','scored']

#method call to make the pie chart
df=pf.pie_attack(parameters,team_effect_weights)
#df.to_csv (r'../data/processed/pie_attack.csv', index = False, header=True)
display(df)

#display the 3d pie chart
pf.plot_pie(team_effect_weights,parameters)
plt.title("Weight of each attacking parameter\n" + "for calcualted weighted average\n")
plt.show()
# Out:
#   parameter  weight
# 0        xG      37
# 1  pressure      24
# 2    scored      39

# %%
#setting up the values and labels of the pie chart
oppo_effect_weights= [34,28,38]
parameters= ['xGA','oppo_pressure','conceded']

#method call to make the pie chart
df=pf.pie_attack(parameters,oppo_effect_weights)
#df.to_csv (r'../data/processed/pie_def.csv', index = False, header=True)
display(df)

#display the 3d pie chart
pf.plot_pie(oppo_effect_weights,parameters)
plt.title("Weight of each defensive parameter\n" + "for calcualted weighted average\n")
plt.show()
# Out:
#        parameter  weight
# 0            xGA      34
# 1  oppo_pressure      28
# 2       conceded      38

# %% [markdown]
# ### Conclusion

# %% [markdown]
# As you can see weight of xG is only 37%. Therefore, teams with the highest xG sometimes end up not winning the league. This is because there are other factors such as pressure, oppo_pressure, xGA, and conceded that determine the position of a team.
